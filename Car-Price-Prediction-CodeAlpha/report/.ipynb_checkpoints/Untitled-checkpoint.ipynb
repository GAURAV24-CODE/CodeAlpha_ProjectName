# %% [markdown]
# # 🚗 Car Price Prediction using Machine Learning
#
# ## 📌 Project Overview
#
# This project predicts the selling price of used cars using Machine Learning.
#
# The workflow includes:
#
# - 📂 Data Loading
# - 🧹 Data Cleaning
# - 📊 Exploratory Data Analysis (EDA)
# - 🔧 Feature Engineering
# - 🤖 Model Building
# - 📈 Model Evaluation
# - 💾 Model Saving
#
# ---
#
# ### 👨‍💻 Author
#
# **Gaurav Eknath Kumbhar**
#
# MCA Student | Aspiring Data Scientist | Machine Learning Enthusiast

# %%
# ==========================================================
# Import Required Libraries
# ==========================================================

# Data Manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# Save Model
import joblib

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Plot Style
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["font.size"] = 12

print("✅ Libraries Imported Successfully")
# Out:
# ✅ Libraries Imported Successfully

# %%
# ==========================================================
# Load Dataset
# ==========================================================

df = pd.read_csv("car data.csv")

print("Dataset Loaded Successfully")

df.head()
# Out:
# Dataset Loaded Successfully
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
# ==========================================================
# Dataset Overview
# ==========================================================

print("="*60)
print("Dataset Shape")
print("="*60)

print(df.shape)

print("\n")

print("="*60)
print("Dataset Information")
print("="*60)

df.info()

print("\n")

print("="*60)
print("Missing Values")
print("="*60)

print(df.isnull().sum())

print("\n")

print("="*60)
print("Duplicate Values")
print("="*60)

print(df.duplicated().sum())
# Out:
# ============================================================
# Dataset Shape
# ============================================================
# (301, 9)
#
#
# ============================================================
# Dataset Information
# ============================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
#
#
# ============================================================
# Missing Values
# ============================================================
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64
#
#
# ============================================================
# Duplicate Values
# ============================================================
# 2

# %%
# ==========================================================
# Statistical Summary
# ==========================================================

df.describe().T.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_e745a_row0_col0, #T_e745a_row0_col2, #T_e745a_row1_col0, #T_e745a_row1_col1, #T_e745a_row1_col2, #T_e745a_row1_col3, #T_e745a_row1_col4, #T_e745a_row1_col5, #T_e745a_row1_col6, #T_e745a_row1_col7, #T_e745a_row2_col0, #T_e745a_row2_col1, #T_e745a_row2_col2, #T_e745a_row2_col3, #T_e745a_row2_col4, #T_e745a_row2_col5, #T_e745a_row2_col6, #T_e745a_row2_col7, #T_e745a_row3_col0, #T_e745a_row4_col0, #T_e745a_row4_col1, #T_e745a_row4_col2, #T_e745a_row4_col3, #T_e745a_row4_col4, #T_e745a_row4_col5, #T_e745a_row4_col6, #T_e745a_row4_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e745a_row0_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_e745a_row0_col3, #T_e745a_row3_col1, #T_e745a_row3_col2, #T_e745a_row3_col4, #T_e745a_row3_col5, #T_e745a_row3_col6, #T_e745a_row3_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e745a_row0_col4 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_e745a_row0_col5 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e745a_row0_col6 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_e745a_row0_col7 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e745a_row3_col3 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# </style>
# <table id="T_e745a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e745a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_e745a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_e745a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_e745a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_e745a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_e745a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_e745a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_e745a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e745a_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_e745a_row0_col0" class="data row0 col0" >301.000000</td>
#       <td id="T_e745a_row0_col1" class="data row0 col1" >2013.627907</td>
#       <td id="T_e745a_row0_col2" class="data row0 col2" >2.891554</td>
#       <td id="T_e745a_row0_col3" class="data row0 col3" >2003.000000</td>
#       <td id="T_e745a_row0_col4" class="data row0 col4" >2012.000000</td>
#       <td id="T_e745a_row0_col5" class="data row0 col5" >2014.000000</td>
#       <td id="T_e745a_row0_col6" class="data row0 col6" >2016.000000</td>
#       <td id="T_e745a_row0_col7" class="data row0 col7" >2018.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e745a_level0_row1" class="row_heading level0 row1" >Selling_Price</th>
#       <td id="T_e745a_row1_col0" class="data row1 col0" >301.000000</td>
#       <td id="T_e745a_row1_col1" class="data row1 col1" >4.661296</td>
#       <td id="T_e745a_row1_col2" class="data row1 col2" >5.082812</td>
#       <td id="T_e745a_row1_col3" class="data row1 col3" >0.100000</td>
#       <td id="T_e745a_row1_col4" class="data row1 col4" >0.900000</td>
#       <td id="T_e745a_row1_col5" class="data row1 col5" >3.600000</td>
#       <td id="T_e745a_row1_col6" class="data row1 col6" >6.000000</td>
#       <td id="T_e745a_row1_col7" class="data row1 col7" >35.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e745a_level0_row2" class="row_heading level0 row2" >Present_Price</th>
#       <td id="T_e745a_row2_col0" class="data row2 col0" >301.000000</td>
#       <td id="T_e745a_row2_col1" class="data row2 col1" >7.628472</td>
#       <td id="T_e745a_row2_col2" class="data row2 col2" >8.642584</td>
#       <td id="T_e745a_row2_col3" class="data row2 col3" >0.320000</td>
#       <td id="T_e745a_row2_col4" class="data row2 col4" >1.200000</td>
#       <td id="T_e745a_row2_col5" class="data row2 col5" >6.400000</td>
#       <td id="T_e745a_row2_col6" class="data row2 col6" >9.900000</td>
#       <td id="T_e745a_row2_col7" class="data row2 col7" >92.600000</td>
#     </tr>
#     <tr>
#       <th id="T_e745a_level0_row3" class="row_heading level0 row3" >Driven_kms</th>
#       <td id="T_e745a_row3_col0" class="data row3 col0" >301.000000</td>
#       <td id="T_e745a_row3_col1" class="data row3 col1" >36947.205980</td>
#       <td id="T_e745a_row3_col2" class="data row3 col2" >38886.883882</td>
#       <td id="T_e745a_row3_col3" class="data row3 col3" >500.000000</td>
#       <td id="T_e745a_row3_col4" class="data row3 col4" >15000.000000</td>
#       <td id="T_e745a_row3_col5" class="data row3 col5" >32000.000000</td>
#       <td id="T_e745a_row3_col6" class="data row3 col6" >48767.000000</td>
#       <td id="T_e745a_row3_col7" class="data row3 col7" >500000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e745a_level0_row4" class="row_heading level0 row4" >Owner</th>
#       <td id="T_e745a_row4_col0" class="data row4 col0" >301.000000</td>
#       <td id="T_e745a_row4_col1" class="data row4 col1" >0.043189</td>
#       <td id="T_e745a_row4_col2" class="data row4 col2" >0.247915</td>
#       <td id="T_e745a_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_e745a_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_e745a_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_e745a_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_e745a_row4_col7" class="data row4 col7" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# First 10 Rows
df.head(5)
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
# ==========================================================
# Data Types
# ==========================================================

dtype_df = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.values,
    "Missing Values": df.isnull().sum().values
})

dtype_df
# Out:
#           Column Data Type  Missing Values
# 0       Car_Name    object               0
# 1           Year     int64               0
# 2  Selling_Price   float64               0
# 3  Present_Price   float64               0
# 4     Driven_kms     int64               0
# 5      Fuel_Type    object               0
# 6   Selling_type    object               0
# 7   Transmission    object               0
# 8          Owner     int64               0

# %%
# ==========================================================
# Missing Values Visualization
# ==========================================================

missing = df.isnull().sum()

plt.figure(figsize=(10,5))

sns.barplot(
    x=missing.index,
    y=missing.values,
    palette="viridis"
)

plt.title("Missing Values in Dataset",fontsize=16)

plt.ylabel("Count")

plt.xticks(rotation=45)

plt.show()

# %%
# ==========================================================
# Remove Duplicate Rows
# ==========================================================

print("Before :",df.shape)

df = df.drop_duplicates()

print("After :",df.shape)
# Out:
# Before : (301, 9)
# After : (299, 9)

# %%
numeric = df.select_dtypes(include=np.number)

numeric.hist(
    figsize=(16,10),
    bins=25,
    color="steelblue",
    edgecolor="black"
)

plt.suptitle("Distribution of Numerical Features",fontsize=18)

plt.show()

# %%
# ==========================================================
# Categorical Features Analysis
# ==========================================================

categorical_columns = ["Fuel_Type", "Selling_type", "Transmission"]

for col in categorical_columns:

    plt.figure(figsize=(8,5))

    sns.countplot(
        data=df,
        x=col,
        palette="viridis"
    )

    plt.title(f"Distribution of {col}", fontsize=15)
    plt.xlabel(col)
    plt.ylabel("Count")

    plt.show()

# %%
# ==========================================================
# Selling Price Distribution
# ==========================================================

plt.figure(figsize=(10,6))

sns.histplot(
    df["Selling_Price"],
    bins=30,
    kde=True,
    color="royalblue"
)

plt.title("Distribution of Selling Price", fontsize=16)
plt.xlabel("Selling Price")
plt.ylabel("Frequency")

plt.show()

# %%
# ==========================================================
# Outlier Detection
# ==========================================================

numerical_columns = [
    "Selling_Price",
    "Present_Price",
    "Driven_kms"
]

for col in numerical_columns:

    plt.figure(figsize=(8,5))

    sns.boxplot(
        x=df[col],
        color="orange"
    )

    plt.title(f"Boxplot of {col}")

    plt.show()

# %%
# ==========================================================
# Correlation Heatmap
# ==========================================================

plt.figure(figsize=(10,7))

corr = df.select_dtypes(include=np.number).corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    linewidths=0.5,
    fmt=".2f"
)

plt.title("Correlation Heatmap", fontsize=16)

plt.show()

# %%
# ==========================================================
# Feature Engineering
# ==========================================================

CURRENT_YEAR = 2025

df["Car_Age"] = CURRENT_YEAR - df["Year"]

df.drop("Year", axis=1, inplace=True)

df.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0     ritz           3.35           5.59       27000    Petrol       Dealer
# 1      sx4           4.75           9.54       43000    Diesel       Dealer
# 2     ciaz           7.25           9.85        6900    Petrol       Dealer
# 3  wagon r           2.85           4.15        5200    Petrol       Dealer
# 4    swift           4.60           6.87       42450    Diesel       Dealer
#
#   Transmission  Owner  Car_Age
# 0       Manual      0       11
# 1       Manual      0       12
# 2       Manual      0        8
# 3       Manual      0       14
# 4       Manual      0       11

# %%
# ==========================================================
# Label Encoding
# ==========================================================

encoder = LabelEncoder()

categorical_columns = [
    "Fuel_Type",
    "Selling_type",
    "Transmission"
]

for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

df.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Driven_kms  Fuel_Type  Selling_type  \
# 0     ritz           3.35           5.59       27000          2             0
# 1      sx4           4.75           9.54       43000          1             0
# 2     ciaz           7.25           9.85        6900          2             0
# 3  wagon r           2.85           4.15        5200          2             0
# 4    swift           4.60           6.87       42450          1             0
#
#    Transmission  Owner  Car_Age
# 0             1      0       11
# 1             1      0       12
# 2             1      0        8
# 3             1      0       14
# 4             1      0       11

# %%
# ==========================================================
# Features and Target
# ==========================================================

X = df.drop("Selling_Price", axis=1)

y = df["Selling_Price"]

print("Features Shape :", X.shape)
print("Target Shape :", y.shape)
# Out:
# Features Shape : (299, 8)
# Target Shape : (299,)

# %%
# ==========================================================
# Train Test Split
# ==========================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Samples :", X_train.shape)
print("Testing Samples :", X_test.shape)
# Out:
# Training Samples : (239, 8)
# Testing Samples : (60, 8)

# %%
print(X_train.dtypes)
# Out:
# Car_Name          object
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type          int64
# Selling_type       int64
# Transmission       int64
# Owner              int64
# Car_Age            int64
# dtype: object

# %%
print(X_train.select_dtypes(include="object").columns)
# Out:
# Index(['Car_Name'], dtype='object')

# %%
print(X.columns.tolist())
# Out:
# ['Car_Name', 'Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type', 'Transmission', 'Owner', 'Car_Age']

# %%
X = df.drop(columns=["Selling_Price", "Car_Name"])
y = df["Selling_Price"]

# %%
# ==========================================================
# Train Test Split
# ==========================================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Samples :", X_train.shape)
print("Testing Samples :", X_test.shape)
# Out:
# Training Samples : (239, 7)
# Testing Samples : (60, 7)

# %%
# ==========================================================
# Model Training
# ==========================================================

models = {

    "Linear Regression": LinearRegression(),

    "Decision Tree": DecisionTreeRegressor(
        random_state=42
    ),

    "Random Forest": RandomForestRegressor(
        n_estimators=200,
        random_state=42
    )

}

results = {}

for name, model in models.items():

    model.fit(X_train, y_train)

    pred = model.predict(X_test)

    score = r2_score(y_test, pred)

    results[name] = score

    print(f"{name} R² Score : {score:.4f}")
# Out:
# Linear Regression R² Score : 0.7410
# Decision Tree R² Score : 0.8252
# Random Forest R² Score : 0.5207

# %%
# ==========================================================
# Model Comparison
# ==========================================================

comparison = pd.DataFrame({

    "Model": results.keys(),

    "R² Score": results.values()

})

comparison = comparison.sort_values(
    by="R² Score",
    ascending=False
)

comparison
# Out:
#                Model  R² Score
# 1      Decision Tree  0.825168
# 0  Linear Regression  0.740993
# 2      Random Forest  0.520729

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=comparison,
    x="R² Score",
    y="Model",
    palette="viridis"
)

plt.title("Model Performance Comparison", fontsize=16)

plt.xlim(0, 1)

plt.show()

# %%
# ==========================================================
# Hyperparameter Tuning
# ==========================================================

from sklearn.model_selection import GridSearchCV

param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 5, 10, 20],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2]
}

grid = GridSearchCV(
    estimator=RandomForestRegressor(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

grid.fit(X_train, y_train)

best_model = grid.best_estimator_

print("Best Parameters:")
print(grid.best_params_)
# Out:
# Best Parameters:
# {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %%
# ==========================================================
# Prediction
# ==========================================================

y_pred = best_model.predict(X_test)

print("Prediction Completed Successfully")
# Out:
# Prediction Completed Successfully

# %%
# ==========================================================
# Evaluation Metrics
# ==========================================================

mae = mean_absolute_error(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print(f"MAE  : {mae:.3f}")
print(f"MSE  : {mse:.3f}")
print(f"RMSE : {rmse:.3f}")
print(f"R²   : {r2:.3f}")
# Out:
# MAE  : 1.465
# MSE  : 11.955
# RMSE : 3.458
# R²   : 0.536

# %%
# ==========================================================
# Actual vs Predicted
# ==========================================================

plt.figure(figsize=(8,6))

plt.scatter(
    y_test,
    y_pred,
    color="royalblue",
    alpha=0.7
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red",
    linewidth=2
)

plt.xlabel("Actual Price")

plt.ylabel("Predicted Price")

plt.title("Actual vs Predicted Selling Price")

plt.grid(True)

plt.show()

# %%
# ==========================================================
# Residual Analysis
# ==========================================================

residuals = y_test - y_pred

plt.figure(figsize=(8,6))

sns.scatterplot(
    x=y_pred,
    y=residuals,
    color="green"
)

plt.axhline(
    y=0,
    color="red",
    linestyle="--"
)

plt.xlabel("Predicted Price")

plt.ylabel("Residuals")

plt.title("Residual Plot")

plt.show()

# %%
# ==========================================================
# Feature Importance
# ==========================================================

importance = pd.DataFrame({

    "Feature": X.columns,

    "Importance": best_model.feature_importances_

})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance
# Out:
#          Feature  Importance
# 0  Present_Price    0.905729
# 6        Car_Age    0.069732
# 1     Driven_kms    0.014841
# 4   Transmission    0.005437
# 3   Selling_type    0.002670
# 2      Fuel_Type    0.001582
# 5          Owner    0.000010

# %%
# ==========================================================
# Feature Importance Plot
# ==========================================================

plt.figure(figsize=(10,6))

sns.barplot(
    data=importance,
    x="Importance",
    y="Feature",
    palette="viridis"
)

plt.title("Feature Importance")

plt.show()

# %%
# ==========================================================
# Save Model
# ==========================================================

joblib.dump(best_model, "car_price_model.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# ==========================================================
# Sample Prediction
# ==========================================================

sample = X.iloc[[0]]

prediction = best_model.predict(sample)

print("Predicted Selling Price : ₹", round(prediction[0],2),"Lakhs")
# Out:
# Predicted Selling Price : ₹ 3.64 Lakhs

# %%
print("="*60)
print("PROJECT COMPLETED SUCCESSFULLY")
print("="*60)

print()

print("Model Used : Random Forest Regressor")

print()

print(f"Final R² Score : {r2:.3f}")

print()

print("The model is now ready for deployment using Streamlit.")
# Out:
# ============================================================
# PROJECT COMPLETED SUCCESSFULLY
# ============================================================
#
# Model Used : Random Forest Regressor
#
# Final R² Score : 0.536
#
# The model is now ready for deployment using Streamlit.

# %%
sns.pairplot(
    df.select_dtypes(include=np.number),
    diag_kind="kde"
)
plt.show()

# %%
df.corr(numeric_only=True).style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_5cef7_row0_col0, #T_5cef7_row1_col1, #T_5cef7_row2_col2, #T_5cef7_row3_col3, #T_5cef7_row4_col4, #T_5cef7_row5_col5, #T_5cef7_row6_col6, #T_5cef7_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5cef7_row0_col1, #T_5cef7_row1_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_5cef7_row0_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_5cef7_row0_col3, #T_5cef7_row0_col4, #T_5cef7_row0_col5, #T_5cef7_row0_col6, #T_5cef7_row0_col7, #T_5cef7_row3_col2, #T_5cef7_row4_col0, #T_5cef7_row4_col1, #T_5cef7_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5cef7_row1_col2 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_5cef7_row1_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5cef7_row1_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_5cef7_row1_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_5cef7_row1_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_5cef7_row1_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_5cef7_row2_col0, #T_5cef7_row7_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5cef7_row2_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5cef7_row2_col3, #T_5cef7_row4_col7, #T_5cef7_row6_col2, #T_5cef7_row6_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_5cef7_row2_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_5cef7_row2_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_5cef7_row2_col6 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5cef7_row2_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_5cef7_row3_col0, #T_5cef7_row5_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5cef7_row3_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5cef7_row3_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_5cef7_row3_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_5cef7_row3_col6, #T_5cef7_row5_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5cef7_row3_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5cef7_row4_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5cef7_row4_col3 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_5cef7_row4_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_5cef7_row4_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_5cef7_row5_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_5cef7_row5_col3, #T_5cef7_row7_col4 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_5cef7_row5_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_5cef7_row5_col7 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_5cef7_row6_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_5cef7_row6_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_5cef7_row6_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_5cef7_row6_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_5cef7_row6_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_5cef7_row7_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_5cef7_row7_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_5cef7_row7_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5cef7_row7_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_5cef7_row7_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# </style>
# <table id="T_5cef7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cef7_level0_col0" class="col_heading level0 col0" >Selling_Price</th>
#       <th id="T_5cef7_level0_col1" class="col_heading level0 col1" >Present_Price</th>
#       <th id="T_5cef7_level0_col2" class="col_heading level0 col2" >Driven_kms</th>
#       <th id="T_5cef7_level0_col3" class="col_heading level0 col3" >Fuel_Type</th>
#       <th id="T_5cef7_level0_col4" class="col_heading level0 col4" >Selling_type</th>
#       <th id="T_5cef7_level0_col5" class="col_heading level0 col5" >Transmission</th>
#       <th id="T_5cef7_level0_col6" class="col_heading level0 col6" >Owner</th>
#       <th id="T_5cef7_level0_col7" class="col_heading level0 col7" >Car_Age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cef7_level0_row0" class="row_heading level0 row0" >Selling_Price</th>
#       <td id="T_5cef7_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5cef7_row0_col1" class="data row0 col1" >0.876305</td>
#       <td id="T_5cef7_row0_col2" class="data row0 col2" >0.028566</td>
#       <td id="T_5cef7_row0_col3" class="data row0 col3" >-0.500292</td>
#       <td id="T_5cef7_row0_col4" class="data row0 col4" >-0.553851</td>
#       <td id="T_5cef7_row0_col5" class="data row0 col5" >-0.348869</td>
#       <td id="T_5cef7_row0_col6" class="data row0 col6" >-0.087880</td>
#       <td id="T_5cef7_row0_col7" class="data row0 col7" >-0.234369</td>
#     </tr>
#     <tr>
#       <th id="T_5cef7_level0_row1" class="row_heading level0 row1" >Present_Price</th>
#       <td id="T_5cef7_row1_col0" class="data row1 col0" >0.876305</td>
#       <td id="T_5cef7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5cef7_row1_col2" class="data row1 col2" >0.205224</td>
#       <td id="T_5cef7_row1_col3" class="data row1 col3" >-0.431887</td>
#       <td id="T_5cef7_row1_col4" class="data row1 col4" >-0.511779</td>
#       <td id="T_5cef7_row1_col5" class="data row1 col5" >-0.334326</td>
#       <td id="T_5cef7_row1_col6" class="data row1 col6" >0.009948</td>
#       <td id="T_5cef7_row1_col7" class="data row1 col7" >0.053167</td>
#     </tr>
#     <tr>
#       <th id="T_5cef7_level0_row2" class="row_heading level0 row2" >Driven_kms</th>
#       <td id="T_5cef7_row2_col0" class="data row2 col0" >0.028566</td>
#       <td id="T_5cef7_row2_col1" class="data row2 col1" >0.205224</td>
#       <td id="T_5cef7_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5cef7_row2_col3" class="data row2 col3" >-0.167287</td>
#       <td id="T_5cef7_row2_col4" class="data row2 col4" >-0.101030</td>
#       <td id="T_5cef7_row2_col5" class="data row2 col5" >-0.163881</td>
#       <td id="T_5cef7_row2_col6" class="data row2 col6" >0.089367</td>
#       <td id="T_5cef7_row2_col7" class="data row2 col7" >0.525714</td>
#     </tr>
#     <tr>
#       <th id="T_5cef7_level0_row3" class="row_heading level0 row3" >Fuel_Type</th>
#       <td id="T_5cef7_row3_col0" class="data row3 col0" >-0.500292</td>
#       <td id="T_5cef7_row3_col1" class="data row3 col1" >-0.431887</td>
#       <td id="T_5cef7_row3_col2" class="data row3 col2" >-0.167287</td>
#       <td id="T_5cef7_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5cef7_row3_col4" class="data row3 col4" >0.347922</td>
#       <td id="T_5cef7_row3_col5" class="data row3 col5" >0.068618</td>
#       <td id="T_5cef7_row3_col6" class="data row3 col6" >0.054174</td>
#       <td id="T_5cef7_row3_col7" class="data row3 col7" >0.046210</td>
#     </tr>
#     <tr>
#       <th id="T_5cef7_level0_row4" class="row_heading level0 row4" >Selling_type</th>
#       <td id="T_5cef7_row4_col0" class="data row4 col0" >-0.553851</td>
#       <td id="T_5cef7_row4_col1" class="data row4 col1" >-0.511779</td>
#       <td id="T_5cef7_row4_col2" class="data row4 col2" >-0.101030</td>
#       <td id="T_5cef7_row4_col3" class="data row4 col3" >0.347922</td>
#       <td id="T_5cef7_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5cef7_row4_col5" class="data row4 col5" >0.058669</td>
#       <td id="T_5cef7_row4_col6" class="data row4 col6" >0.123646</td>
#       <td id="T_5cef7_row4_col7" class="data row4 col7" >0.036820</td>
#     </tr>
#     <tr>
#       <th id="T_5cef7_level0_row5" class="row_heading level0 row5" >Transmission</th>
#       <td id="T_5cef7_row5_col0" class="data row5 col0" >-0.348869</td>
#       <td id="T_5cef7_row5_col1" class="data row5 col1" >-0.334326</td>
#       <td id="T_5cef7_row5_col2" class="data row5 col2" >-0.163881</td>
#       <td id="T_5cef7_row5_col3" class="data row5 col3" >0.068618</td>
#       <td id="T_5cef7_row5_col4" class="data row5 col4" >0.058669</td>
#       <td id="T_5

# %%
df.to_csv("cleaned_car_data.csv", index=False)

# %%
importance.to_csv("feature_importance.csv", index=False)

# %% [markdown]
# """# 🎉 Thank You!
#
# ## Project Completed Successfully
#
# #**Author:** Gaurav Eknath Kumbhar#
#
# ### Skills Demonstrated
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Machine Learning
# - Hyperparameter Tuning
# - Model Evaluation
# - Model Persistence
#
# 0#⭐ Thank you for exploring this project!#"""

# %%
print(X.columns.tolist())
# Out:
# ['Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type', 'Transmission', 'Owner', 'Car_Age']

# %%
X.columns
# Out:
# Index(['Present_Price', 'Driven_kms', 'Fuel_Type', 'Selling_type',
#        'Transmission', 'Owner', 'Car_Age'],
#       dtype='object')

# %%
print(df["Fuel_Type"].unique())
print(df["Selling_type"].unique())
print(df["Transmission"].unique())
# Out:
# [2 1 0]
# [0 1]
# [1 0]

# %%
plot_df = df.copy()

plot_df["Fuel_Type"] = plot_df["Fuel_Type"].replace({
    0: "CNG",
    1: "Diesel",
    2: "Petrol"
})

plot_df["Selling_type"] = plot_df["Selling_type"].replace({
    0: "Dealer",
    1: "Individual"
})

plot_df["Transmission"] = plot_df["Transmission"].replace({
    0: "Automatic",
    1: "Manual"
})

# %%
df
# Out:
#     Car_Name  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz           3.35           5.59       27000          2
# 1        sx4           4.75           9.54       43000          1
# 2       ciaz           7.25           9.85        6900          2
# 3    wagon r           2.85           4.15        5200          2
# 4      swift           4.60           6.87       42450          1
# ..       ...            ...            ...         ...        ...
# 296     city           9.50          11.60       33988          1
# 297     brio           4.00           5.90       60000          2
# 298     city           3.35          11.00       87934          2
# 299     city          11.50          12.50        9000          1
# 300     brio           5.30           5.90        5464          2
#
#      Selling_type  Transmission  Owner  Car_Age
# 0               0             1      0       11
# 1               0             1      0       12
# 2               0             1      0        8
# 3               0             1      0       14
# 4               0             1      0       11
# ..            ...           ...    ...      ...
# 296             0             1      0        9
# 297             0             1      0       10
# 298             0             1      0       16
# 299             0             1      0        8
# 300             0             1      0        9
#
# [299 rows x 9 columns]

# %%
plot_df
# Out:
#     Car_Name  Selling_Price  Present_Price  Driven_kms Fuel_Type Selling_type  \
# 0       ritz           3.35           5.59       27000    Petrol       Dealer
# 1        sx4           4.75           9.54       43000    Diesel       Dealer
# 2       ciaz           7.25           9.85        6900    Petrol       Dealer
# 3    wagon r           2.85           4.15        5200    Petrol       Dealer
# 4      swift           4.60           6.87       42450    Diesel       Dealer
# ..       ...            ...            ...         ...       ...          ...
# 296     city           9.50          11.60       33988    Diesel       Dealer
# 297     brio           4.00           5.90       60000    Petrol       Dealer
# 298     city           3.35          11.00       87934    Petrol       Dealer
# 299     city          11.50          12.50        9000    Diesel       Dealer
# 300     brio           5.30           5.90        5464    Petrol       Dealer
#
#     Transmission  Owner  Car_Age
# 0         Manual      0       11
# 1         Manual      0       12
# 2         Manual      0        8
# 3         Manual      0       14
# 4         Manual      0       11
# ..           ...    ...      ...
# 296       Manual      0        9
# 297       Manual      0       10
# 298       Manual      0       16
# 299       Manual      0        8
# 300       Manual      0        9
#
# [299 rows x 9 columns]

# %%
print(df.columns)
# Out:
# Index(['Car_Name', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Fuel_Type',
#        'Selling_type', 'Transmission', 'Owner', 'Car_Age'],
#       dtype='object')

# %%
print(df["Fuel_Type"].head())
# Out:
# 0    2
# 1    1
# 2    2
# 3    2
# 4    1
# Name: Fuel_Type, dtype: int64
